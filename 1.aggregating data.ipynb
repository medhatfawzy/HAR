# %%
import pandas as pd

# %%
X_train = pd.read_csv('data/train/X_train.txt', delim_whitespace=True, header=None)
X_train_columns = pd.read_csv('data/features.txt', delim_whitespace=True, header=None)
X_train_subject = pd.read_csv('data/train/subject_train.txt', delim_whitespace=True, header=None)

# %%
X_train
# Out:
#            0         1         2         3         4         5         6    \
# 0     0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1     0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2     0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3     0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4     0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
# ...        ...       ...       ...       ...       ...       ...       ...
# 7347  0.299665 -0.057193 -0.181233 -0.195387  0.039905  0.077078 -0.282301
# 7348  0.273853 -0.007749 -0.147468 -0.235309  0.004816  0.059280 -0.322552
# 7349  0.273387 -0.017011 -0.045022 -0.218218 -0.103822  0.274533 -0.304515
# 7350  0.289654 -0.018843 -0.158281 -0.219139 -0.111412  0.268893 -0.310487
# 7351  0.351503 -0.012423 -0.203867 -0.269270 -0.087212  0.177404 -0.377404
#
# ...

# %%
# Checking for duplication
X_train_columns[1].value_counts()
# Out:
# tBodyAcc-mean()-X            1
# fBodyAccJerk-skewness()-Y    1
# fBodyAccJerk-maxInds-Z       1
# fBodyAccJerk-meanFreq()-X    1
# fBodyAccJerk-meanFreq()-Y    1
#                             ..
# tBodyGyroJerk-iqr()-Z        1
# tBodyGyroJerk-iqr()-Y        1
# tBodyGyroJerk-iqr()-X        1
# tBodyGyroJerk-energy()-Z     1
# angle(Z,gravityMean)         1
# Name: 1, Length: 561, dtype: int64

# %% [markdown]
# Some duplication in the columns names were found. Those were fixed in the features.txt file.

# %%
X_train_subject
# Out:
#        0
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ...   ..
# 7347  30
# 7348  30
# 7349  30
# 7350  30
# 7351  30
#
# [7352 rows x 1 columns]

# %%
X_train_columns = X_train_columns[1].tolist()
X_train.columns = X_train_columns
X_train['subject'] = X_train_subject

# %%
X_train
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
y_train = pd.read_csv('data/train/y_train.txt', delim_whitespace=True, header=None)
y_train.columns = ['activity']

y_train_labels = pd.read_csv('data/activity_labels.txt', delim_whitespace=True, header=None)
y_train_labels = y_train_labels[1].tolist()

# %%
y_train.activity.value_counts()
# Out:
# 6    1407
# 5    1374
# 4    1286
# 1    1226
# 2    1073
# 3     986
# Name: activity, dtype: int64

# %%
y_train_labels
# Out:
# ['WALKING',
#  'WALKING_UPSTAIRS',
#  'WALKING_DOWNSTAIRS',
#  'SITTING',
#  'STANDING',
#  'LAYING']

# %%
# replce the numbers with the labels
y_train.activity = y_train.activity.map(lambda x: y_train_labels[x-1])

# %%
y_train.activity.value_counts()
# Out:
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: activity, dtype: int64

# %%
train_data = pd.concat([X_train, y_train], axis=1)

# %%
train_data
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.288585          -0.020294          -0.132905
# 1              0.278419          -0.016411          -0.123520
# 2              0.279653          -0.019467          -0.113462
# 3              0.279174          -0.026201          -0.123283
# 4              0.276629          -0.016570          -0.115362
# ...                 ...                ...                ...
# 7347           0.299665          -0.057193          -0.181233
# 7348           0.273853          -0.007749          -0.147468
# 7349           0.273387          -0.017011          -0.045022
# 7350           0.289654          -0.018843          -0.158281
# 7351           0.351503          -0.012423          -0.203867
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.995279         -0.983111         -0.913526         -0.995112
# ...

# %%
train_data.to_parquet('data/train_data.parquet')

# %%
X_test = pd.read_csv('data/test/X_test.txt', delim_whitespace=True, header=None)
X_test.columns = X_train_columns
X_test_subject = pd.read_csv('data/test/subject_test.txt', delim_whitespace=True, header=None)

y_test = pd.read_csv('data/test/y_test.txt', delim_whitespace=True, header=None)
y_test.columns = ['activity']

y_test.activity = y_test.activity.map(lambda x: y_train_labels[x-1])

# %%
X_test['subject'] = X_test_subject
X_test
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# ...

# %%
test_data = pd.concat([X_test, y_test], axis=1)

# %%
test_data
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 0              0.257178          -0.023285          -0.014654
# 1              0.286027          -0.013163          -0.119083
# 2              0.275485          -0.026050          -0.118152
# 3              0.270298          -0.032614          -0.117520
# 4              0.274833          -0.027848          -0.129527
# ...                 ...                ...                ...
# 2942           0.310155          -0.053391          -0.099109
# 2943           0.363385          -0.039214          -0.105915
# 2944           0.349966           0.030077          -0.115788
# 2945           0.237594           0.018467          -0.096499
# 2946           0.153627          -0.018437          -0.137018
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 0            -0.938404         -0.920091         -0.667683         -0.952501
# ...

# %%
test_data.to_parquet('data/test_data.parquet')
